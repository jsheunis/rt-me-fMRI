# %%
import numpy as np
import nibabel as nib
import os
import pandas as pd

data_dir = '/Volumes/Stephan_WD/Kempenhaeghe_data/Kempenhaeghe demo'

single_func_nii = os.path.join(data_dir, 'demo_rt-fMRI_WIP_FE_EPI_dyn1_SENSE_3_1.nii') 
single_func_par = os.path.join(data_dir, 'demo_rt-fMRI_WIP_FE_EPI_dyn1_SENSE_3_1.PAR')
single_func_rec = os.path.join(data_dir, 'demo_rt-fMRI_WIP_FE_EPI_dyn1_SENSE_3_1.REC')

dump_func_nii = os.path.join(data_dir, '0047', 'Dump-0001.nii')
dump_func_par = os.path.join(data_dir, '0047', 'Dump-0001.par')
dump_func_rec = os.path.join(data_dir, '0047', 'Dump-0001.rec')

img = nib.load(single_func_nii)
print(img.shape)
print(img.get_data_dtype() == np.dtype(np.int16))
print(img.affine.shape)
data = img.get_fdata()
print(data.shape)
print(type(data))
hdr = img.header
print(hdr)


partable = pd.read_table(single_func_par)
print(partable)


# print(hdr.get_xyzt_units())
# raw = hdr.structarr
# print(raw)
# print(raw['xyzt_units'])

# general_info, image_info = nib.parrec.parse_PAR_header(single_func_par)

# hdrpar = nib.parrec.PARRECHeader(general_info, image_info)


# general_info, image_info = nib.parrec.parse_PAR_header(single_func_par)

# print(hdrpar)

# data = np.ones((32, 32, 15, 100), dtype=np.int16)
# new_img = nib.Nifti1Image(data, np.eye(4))
# new_img.get_data_dtype() == np.dtype(np.int16)
# new_img.header.get_xyzt_units()
# new_img.to_filename(os.path.join('build','test4d.nii.gz'))
# nib.save(new_img, os.path.join('build','test4d.nii.gz'))
# Out:
# (128, 128, 45)
# True
# (4, 4)
# (128, 128, 45)
# <class 'numpy.ndarray'>
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b''
# dim_info        : 0
# dim             : [  3 128 128  45   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.        1.8666667 1.8666667 3.        0.        0.        0.
#  0.       ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 44
# slice_code      : unknown
# xyzt_units      : 2
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'Philips Medical Systems Achieva 5.1.7 '
# aux_file        : b''
# qform_code      : scanner
# sform_code      : unknown
# quatern_b       : 0.049945746
# quatern_c       : -0.14770076
# quatern_d       : 0.98765266
# qoffset_x       : 126.00694
# qoffset_y       : 135.94531
# qoffset_z       : 15.956648
# srow_x          : [1. 0. 0. 0.]
# srow_y          : [0. 1. 0. 0.]
# srow_z          : [0. 0. 1. 0.]
# intent_name     : b''
# magic           : b'n+1'

# %%
main_dir = '/Users/jheunis/Desktop/sample-data/sub-neufepmetest/sub-pilot/raw-data'
parfile = main_dir + '/pilot_sub_01_NEUFEP-ME-emotion1_SENSE_5_1.txt'
partable = pd.read_table(parfile, sep='t', skiprows=100)
print(partable)
# Out:
#        17   3    3  1 0 2   100  16   100   64   64     0.00000   0.73773 2.06999e-003   852  1481   2.62  -0.86  -5.77   -0.65    2.00   -2.24  3.500  0.000 0 1 1 2  3.500  3.500  42.00    4.00     0.00    0.00   1   90.00     0    0    0    75   0.0  1   1    8    0   0.000    0.000    0.000  1
# 0       18   1    4  1 0 2   101  16   100   64   64 ...
# 1       18   2    4  1 0 2   102  16   100   64   64 ...
# 2       18   3    4  1 0 2   103  16   100   64   64 ...
# 3       19   1    4  1 0 2   104  16   100   64   64 ...
# 4       19   2    4  1 0 2   105  16   100   64   64 ...
# ...                                                  ...
# 21314   34   3  206  1 0 2 21415  16   100   64   64 ...
# 21315   34   3  207  1 0 2 21416  16   100   64   64 ...
# 21316   34   3  208  1 0 2 21417  16   100   64   64 ...
# 21317   34   3  209  1 0 2 21418  16   100   64   64 ...
# 21318   34   3  210  1 0 2 21419  16   100   64   64 ...
#
# [21319 rows x 1 columns]

# %%
# from nibabel.openers import ImageOpener
# from nibabel.parrec import parse_PAR_header

# parfile = single_func_par
# with ImageOpener(parfile, 'rt') as _fobj:
#     HDR_INFO, HDR_DEFS = parse_PAR_header(_fobj)
    
# print(HDR_INFO)
# print(type(HDR_INFO))

# print(HDR_DEFS)
# print(type(HDR_DEFS))
